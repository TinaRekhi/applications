# %%
#import libraries
import requests
from datetime import datetime as dt
from datetime import timedelta
import pandas as pd
import math
from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# get events from n days ago
iso = 562 #Look in ACLED documentation ISO code for number this is for Niger
limit = 400

api_url = 'https://api.acleddata.com/acled/read?terms=accept&iso={}'.format(iso)
print (api_url, type(api_url)) #creates request according to ACLED format specifications - p. 13
# Out:
# https://api.acleddata.com/acled/read?terms=accept&iso=562 <class 'str'>

# %%
response = requests.get(api_url)
data = response.json()
data.keys()
data['count']
# Out:
# 500

# %% [markdown]
# ### From the documentation we know this is the max return --- How can we get all the results?

# %%
# Let's mkae a function that updates our search to get the new pages

def ping_acled(api_url): 
    '''
    Takes one parameter search term for API
    '''
    
    response = requests.get(api_url)
    data = response.json()
    return data

# %%
results = [] # empty data strcture to store results
num_results = 500 # condition to continue adding pages
count = 0  # tracker of results
page = 1 #Per the documentation each page will give us more results

while num_results == 500: #if less 500 or 0 we know we have all the results
    print ("starting ", page, " ", num_results) #just to see our progress
    api_url = 'https://api.acleddata.com/acled/read?terms=accept&iso={}&page={}'.format(iso,page) #the search
    data = ping_acled(api_url) #call the previous function 
    results.append(data['data']) #store in our results
    count += data['count'] #Track number of results
    num_results = data['count'] #update our condition
    page += 1 #update our page variable
    print ("Total Results ", count) #Track our progress
# Out:
# starting  1   500
# Total Results  500
# starting  2   500
# Total Results  1000
# starting  3   500
# Total Results  1401

# %%
#Now I want to put them together into one giant result
super_list = []
for res in results: 
    super_list += res
    print (len(super_list))
# Out:
# 500
# 1000
# 1401

# %%
#convert it into an pandas data frame or just use your data structure and do more stuff
niger_res = pd.DataFrame(super_list)
niger_res.head()
# Out:
#    data_id  iso event_id_cnty event_id_no_cnty  event_date  year  \
# 0  7228161  562       NIR1452             1452  2020-09-18  2020
# 1  7228145  562       NIR1450             1450  2020-09-18  2020
# 2  7228153  562       NIR1453             1453  2020-09-18  2020
# 3  7228156  562       NIR1449             1449  2020-09-18  2020
# 4  7228158  562       NIR1451             1451  2020-09-18  2020
#
#   time_precision                  event_type                  sub_event_type  \
# 0              1  Violence against civilians  Abduction/forced disappearance
# 1              1  Explosions/Remote violence   Remote explosive/landmine/IED
# 2              1  Violence against civilians  Abduction/forced disappearance
# 3              1  Explosions/Remote violence   Remote explosive/landmine/IED
# 4              1  Violence against civilians  Abduction/forced disappearance
#
#                                               actor1  ...     location  \
# 0  Islamic State (West Africa) and/or Boko Haram ...  ...      Waragou
# 1  Islamic State (West Africa) and/or Boko Haram ...  ...        Bosso
# 2  Islamic State (West Africa) and/or Boko Haram ...  ...        Youwa
# 3  Islamic State (West Africa) and/or Boko Haram ...  ...  Baroua Gana
# 4  Islamic State (West Africa) and/or Boko Haram ...  ...    Makintari
#
#   latitude longitude geo_precision    source source_scale  \
# 0  13.5316   12.7309             1  Whatsapp    New media
# 1  13.6987   13.3095             1  Whatsapp    New media
# 2  13.4671   12.8197             1  Whatsapp    New media
# 3  13.8986   13.1544             1  Whatsapp    New media
# 4  13.5337   12.8181             1  Whatsapp    New media
#
#                                                notes fatalities   timestamp  \
# 0  On 18 September 2020, presumed ISWAP or Boko H...          0  1600717738
# 1  On 18 September 2020, a Nigerien army vehicle ...          1  1600717738
# 2  On 18 September 2020, presumed ISWAP or Boko H...          0  1600717738
# 3  On 18 September 2020, a Nigerien army vehicle ...          0  1600717738
# 4  On 18 September 2020, presumed ISWAP or Boko H...          0  1600717738
#
#   iso3
# 0  NER
# 1  NER
# 2  NER
# 3  NER
# 4  NER
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Do the right thing, take some time to look at the codebook and see what these columns are

# %%
niger_res.columns
# Out:
# Index(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'event_date',
#        'year', 'time_precision', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2', 'inter2',
#        'interaction', 'region', 'country', 'admin1', 'admin2', 'admin3',
#        'location', 'latitude', 'longitude', 'geo_precision', 'source',
#        'source_scale', 'notes', 'fatalities', 'timestamp', 'iso3'],
#       dtype='object')

# %% [markdown]
# ### Homework --- Make a map of some ACLED Data (absolutely use the code from the Global Terrorism Database exercise)

# %%
attacks_by_group = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by group
for index, row in niger_res.iterrows(): 
    if row["actor1"]  in attacks_by_group.keys():
        attacks_by_group[row["actor1"]] += 1 #if group is in the dictionary add 1 attack
    else:
        attacks_by_group[row["actor1"]] = 1 #add group name to dictionary if not in dictionary

attacks_by_group 
#type(float(niger_res["latitude"][0]))
# Out:
# {'Islamic State (West Africa) and/or Boko Haram - Jamatu Ahli is-Sunnah lid-Dawatai wal-Jihad': 205,
#  'Unidentified Armed Group (Niger)': 145,
#  'Military Forces of France (2017-)': 15,
#  'Boko Haram - Jamatu Ahli is-Sunnah lid-Dawatai wal-Jihad': 28,
#  'JNIM: Group for Support of Islam and Muslims and/or Islamic State (Greater Sahara)': 47,
#  'Islamic State (West Africa)': 135,
#  'Fulani Ethnic Militia (Niger)': 5,
#  'Rioters (Niger)': 104,
#  'UFPR: Union of Patriotic Forces for the Refoundation of the Republic': 1,
#  'Military Forces of Niger (2011-)': 102,
#  'Government of Niger (2011-)': 18,
#  'Military Forces of the United States (2017-)': 1,
#  'Islamic State (Greater Sahara)': 149,
#  'Police Forces of Niger (2011-) National Guard': 2,
#  'Islamist Militia (Niger)': 4,
#  'Buduma Ethnic Militia (Niger)': 1,
#  'Military Forces of Niger (2011-) Gendarmerie': 8,
#  'Protesters (Niger)': 128,
#  'Unidentified Armed Group (Nigeria)': 6,
#  'Rioters (Nigeria)': 1,
#  'JNIM: Group for Support of Islam and Muslims': 10,
#  'Rioters (International)': 1,
#  'Military Forces of Chad (1990-)': 2,
#  'Police Forces of Niger (2011-)': 16,
#  'MNJTF: Multinational Joint Task Force': 6,
#  'Kiki Communal Militia (Niger)': 1,
#  'Lamana Communal Militia (Niger)': 1,
#  'Military Forces of Burkina Faso (2015-)': 6,
#  'Rioters (Sudan)': 2,
#  'Protesters (Sudan)': 7,
#  'G5S: G5 Sahel Force (2017-)': 2,
#  'Protesters (Ethiopia)': 1,
#  'Unidentified Communal Militia (Niger)': 12,
#  'Kanuri Ethnic Militia (Niger)': 1,
#  'Dawsahak Ethnic Militia (Niger)': 2,
#  'MSA: Movement for Azawad Salvation': 16,
#  'Chetimari Communal Militia (Niger)': 1,
#  'MJRN: Movement for Justice and the Rehabilitation of Niger': 3,
#  'Tin Gara Communal Militia (Niger)': 1,
#  'Unidentified Armed Group (Chad)': 2,
#  'GATIA: Imghad Tuareg and Allies Self-Defense Group': 4,
#  'Tuareg Ethnic Militia (Mali)': 1,
#  'Arab Ethnic Militia (Niger)': 1,
#  'Toubou Ethnic Militia (Niger)': 2,
#  'Police Forces of Niger (2011-) Green Guards': 1,
#  'Al Mourabitoune Battalion': 1,
#  'MSF: Multinational Security Force': 1,
#  'Hausa Ethnic Militia (Niger)': 1,
#  'AQIM: Al Qaeda in the Islamic Maghreb': 9,
#  'Koglweogo Militia': 1,
#  'Ansar Dine': 1,
#  'Emirate of the Sahara': 1,
#  'Unidentified Military Forces': 2,
#  'MUJAO: Movement for Unity and Jihad in West Africa': 4,
#  'Military Forces of Nigeria (1999-2015)': 2,
#  'Military Forces of France (2012-2017)': 4,
#  'GMA: Mourabitounes Group of Azawad': 1,
#  'Those Who Signed in Blood': 1,
#  'Military Forces of the United States (2009-2017)': 1,
#  'Military Forces of Niger (2010-2011)': 5,
#  'Military Forces of Algeria (1999-)': 1,
#  'CSRD: Supreme Council for the Restoration of Democracy': 1,
#  'Military Forces of Niger (1999-2010)': 20,
#  'MNJ: Nigerien Movement for Justice': 40,
#  'FARS: Revolutionary Armed Forces of the Sahara': 5,
#  'FLAA: The Air and Azawagh Liberation Front': 6,
#  'Dosso Ethnic Militia (Niger)': 1,
#  'Fassi Ethnic Militia (Niger)': 1,
#  'Police Forces of Nigeria (1999-2015)': 2,
#  'Mutiny of Military Forces of Niger (2000-2010)': 1,
#  'Mutiny of Military Forces of Niger (1999-2010)': 33,
#  'Police Forces of Niger (1999-2010)': 1,
#  'Rioters (Benin)': 1,
#  'Police Forces of Niger (1996-1999)': 5,
#  'Mutiny of Military Forces of Niger (1996-1999)': 28,
#  'Diawondo Ethnic Militia (Niger)': 1,
#  'ADIN: Association for the Propagation of Islam in Niger': 1,
#  'Tuareg Ethnic Militia (Niger)': 3,
#  'Military Forces of Niger (1996-1999)': 5,
#  'FDR: Democratic Front for Renewal': 2,
#  'Islamist Militia (Algeria)': 1}

# %%
# Make X and Y axis for a bar chart plotting attacks
groups = list(attacks_by_group.keys())
attacks = list(attacks_by_group.values())



#niger_res["latitude"][0]

# %%
#Sort from smallest to largest
sorted_groups = sorted(groups, key=lambda x: attacks[groups.index(x)])
sorted_attacks = sorted(attacks)
#float(niger_res["latitude"][2])

# %%
# Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
# makes the figure
p = figure(x_range = sorted_groups, plot_width=800, plot_height=1200,)
#Plots the data
p.vbar(x=sorted_groups, width=0.5, bottom=0,
       top= sorted_attacks, color="blue")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis

# %%
show(p)
# Out:
#   <div class="bk-root" id="a1807829-0674-4aec-b14f-2d7751eecae1" data-root-id="1358"></div>

# %%
#Imports necessary aspects of Bokeh for plotting on a map
from bokeh.tile_providers import get_provider, Vendors
from pyproj import Transformer
tile_provider = get_provider('STAMEN_TERRAIN')

# %%
# Take the data reduced to a country and get the lat/long of the attacks and the name of the group
country_map = niger_res[["latitude", 'longitude', 'actor1']]

#see the data this time first 7 rows
country_map.head(7)
# Out:
#   latitude longitude                                             actor1
# 0  13.5316   12.7309  Islamic State (West Africa) and/or Boko Haram ...
# 1  13.6987   13.3095  Islamic State (West Africa) and/or Boko Haram ...
# 2  13.4671   12.8197  Islamic State (West Africa) and/or Boko Haram ...
# 3  13.8986   13.1544  Islamic State (West Africa) and/or Boko Haram ...
# 4  13.5337   12.8181  Islamic State (West Africa) and/or Boko Haram ...
# 5  13.5997    6.4837                   Unidentified Armed Group (Niger)
# 6  14.2495   13.1092  Islamic State (West Africa) and/or Boko Haram ...

# %%
#create pyproj transformer to convert form lat/long to web mercator
transformer = Transformer.from_crs('epsg:4326','epsg:3857')

# %%
country_map["latitude"]=pd.to_numeric(country_map["latitude"])
country_map["longitude"]=pd.to_numeric(country_map["longitude"])
type(country_map["latitude"][0])
# Out:
# <ipython-input-27-f9199690dc03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_map["latitude"]=pd.to_numeric(country_map["latitude"])
# <ipython-input-27-f9199690dc03>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_map["longitude"]=pd.to_numeric(country_map["longitude"])
# numpy.float64

# %%
map_dict = {} # empty dictionary to track group attacks by lat long
nan_count = {} # some data doesn't have a lat/long so we need to know what we are losing



# Iterate through tables and associate group with lat/long
for idx, row in country_map.iterrows():    
    if row['actor1'] in map_dict.keys(): 
        if math.isnan(row["latitude"]):
            #This counts no data
            if row['actor1'] in nan_count.keys(): 
                nan_count[row['actor1']] += 1 
            else: 
                nan_count[row['actor1']] = 1
        else: 
            #This has to convert the lat/long to a mercator projection 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['actor1']].append([point[0],point[1]]) 
    #BOTH the if an else statement do the same thing but since it is a dictionary one needs to add the group name first
    else:  
        if math.isnan(row["latitude"]):
          nan_count[row['actor1']] = 1
        else: 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['actor1']] =[[point[0],point[1]]]
        
#This tells how many attacks we are losing
nan_count  

#float(niger_res["latitude"][2])
# Out:
# {}

# %%
pts = [(6.00,-2.00), (20.00, 10.90)]
bbox = []
for pt in transformer.itransform(pts): 
    bbox.append(pt)

# %%
NPA_x = []
NPA_y = []
for k,v in map_dict.items(): 
    for pt in v:
        NPA_x.append(pt[0])
        NPA_y.append(pt[1])

# %%
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
p.circle(x = NPA_x, y = NPA_y, color= "blue")


#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="e124383d-f8a5-48bd-b16f-4283a6fab90c" data-root-id="1783"></div>

# %%
# reduce the dataframe down to just the philippines
country = GTD[GTD["country_txt"]=="Niger"] # store the information in an object called country
#you can change Philippines to any country in the dataset
country.head(10) #by putting in 10 I changed the default setting of 1st 5 rows to 1st 10 rows
